# %%
import pandas as pd

# %%
data = pd.read_csv(r"G:\My Drive\Data-Centric Solutions\07. Blog Posts\kedro\data\creditcard.csv")

# %%
from ludwig.api import LudwigModel
model = LudwigModel.load(r"C:\Users\johna\anaconda3\envs\precision-recall-env\Precision_Recall_Curves\model\experiment_run_7\model")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 from ludwig.api import LudwigModel
# ----> 2 model = LudwigModel.load(r"C:\Users\johna\anaconda3\envs\precision-recall-env\Precision_Recall_Curves\model\experiment_run_7\model")
#
# File ~\anaconda3\envs\precision-recall-env\lib\site-packages\ludwig\api.py:1507, in LudwigModel.load(model_dir, logging_level, backend, gpus, gpu_memory_limit, allow_parallel_threads, callbacks)
#    1505 # generate model from config
#    1506 set_saved_weights_in_checkpoint_flag(config_obj)
# -> 1507 ludwig_model.model = LudwigModel.create_model(config_obj)
#    1509 # load model weights
#    1510 ludwig_model.load_weights(model_dir)
#
# File ~\anaconda3\envs\precision-recall-env\lib\site-packages\ludwig\api.py:1660, in LudwigModel.create_model(config_obj, random_seed)
#    1648 """Instantiates BaseModel object.
#    1649
# ...
